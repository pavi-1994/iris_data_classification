# %% [markdown]
# Iris Dataset
#
# problem statement:
#
# To clean the data, find the missing values and visualise that our dataset is balanced with equal records for all three species on the iris dataset.
#
# #### Iris Dataset –
#
# The Iris flower data set or Fisher's Iris data set is a multivariate dataset introduced by the British statistician, eugenicist, and biologist Ronald Fisher in his 1936 paper. The data set consists of samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). The features present in the dataset are:
#
# 1)Id
#
# 2)SepalWidthCm
#
# 3)SepalLengthCm
#
# 4)PetalWidthCm
#
# 5)PetalLengthCm
#
# 6)Species
#
# Dataset link: https://www.kaggle.com/datasets/uciml/iris

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
iris_df= pd.read_csv("C:\\Users\\pavik\\Documents\\iris_assignment\\Iris.csv")
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# we will check the full information of the iris_df
#
# #### since the "Id" and the index column of the data set are  similar to each other, will set index column as  Id itself

# %%
iris_df=iris_df.set_index("Id")
iris_df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
print("Shape of iris_df: "+str(iris_df.shape))
print("\n \ncolumn names  of iris_df:\n"+str(iris_df.columns))
# Out:
# Shape of iris_df: (150, 5)
#
#
# column names  of iris_df:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
# from this we come to know that there are 5 columns they are 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm' are float64 datatype and 'Species' column are object datatype. And also it contains 150 non-null rows.
#
# let's see presence of null value and duplicate values in the dataframe
#
# #### Data preprocessing
#
# Missing and Duplicated values

# %%
print("Presence of null values in iris_df:\n"+ "\n"+str( iris_df.isnull().sum()))
print("\n\npresence of duplicated  rows in iris_df:"+str(iris_df.duplicated().sum()))
# Out:
# Presence of null values in iris_df:
#
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#
#
# presence of duplicated  rows in iris_df:3

# %%
iris_df=iris_df.drop_duplicates()
print("after droping the duplicate value shape of iris_df :" + str(iris_df.shape))
# Out:
# after droping the duplicate value shape of iris_df :(147, 5)

# %% [markdown]
# #### If your dataset simply has duplicate rows, there is no need to worry about preserving the data, it is already a part of the finished dataset and you can merely remove or drop these rows from your cleaned data.

# %%
iris_df[iris_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %% [markdown]
# ### Univariant analysis
#
# ### Checking whether Data is balanced or not:

# %%
# Barplot describes the count of the class labels
print(iris_df['Species'].value_counts())
print("\n")
plt.figure(figsize = (12, 6))
sns.countplot(data =iris_df, x = 'Species')
# Out:
# Iris-versicolor    50
# Iris-virginica     49
# Iris-setosa        48
# Name: Species, dtype: int64
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %% [markdown]
# let's check the data distribution for each feature:

# %%
iris_df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     147.000000    147.000000     147.000000    147.000000
# mean        5.856463      3.055782       3.780272      1.208844
# std         0.829100      0.437009       1.759111      0.757874
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.400000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
# Barplot describes the count of the SepalLengthCm
plt.figure(figsize = (12, 6))
sns.countplot(data =iris_df, x = 'SepalLengthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='count'>

# %%
# Barplot describes the count of the SepalWidthCm
plt.figure(figsize = (12, 6))
sns.countplot(data =iris_df, x = 'SepalWidthCm')
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='count'>

# %%
# Barplot describes the count of the SepalWidthCm
plt.figure(figsize = (12, 6))
sns.countplot(data =iris_df, x = 'PetalWidthCm')
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='count'>

# %%
# Barplot describes the count of the SepalWidthCm
plt.figure(figsize = (12, 6))
sns.countplot(data =iris_df, x = 'PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='count'>

# %% [markdown]
# In SepalLengthCm we can see that more than 50% of data distributed between 4.8cm-6.8cm. and it doesnot contain any negative values.
#
# In SepalWidthCm we can see that maore than 50% value lies between 2.4cm and 3.6cm and doesnot contain any negative values.
#
# In PetalWidthCm we can see that more than 50% data values lies between 0.1cm and 2.0cm. It doesnot contains negative values.
#
# In PetalLengthCm we can see that more than 50% data values lies between 1.0cm and 5.2cm. It  doesnot contains negative values.

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.boxplot(x='Species',y='PetalLengthCm',data=iris_df)
plt.subplot(2,2,2)
sns.boxplot(x='Species',y='PetalWidthCm',data=iris_df)
plt.subplot(2,2,3)
sns.boxplot(x='Species',y='SepalLengthCm',data=iris_df)
plt.subplot(2,2,4)
sns.boxplot(x='Species',y='SepalWidthCm',data=iris_df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %% [markdown]
# ### Checking Prescence of outlier and removing it

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.boxplot(iris_df['PetalLengthCm'])
plt.title("Box Plot for PetalLengthCm")
plt.subplot(2,2,2)
sns.boxplot(iris_df['PetalWidthCm'])
plt.title("Box Plot for PetalWidthCm")
plt.subplot(2,2,3)
sns.boxplot(iris_df['SepalWidthCm'])
plt.title("Box Plot for SepalWidthCm")
plt.subplot(2,2,4)
sns.boxplot(iris_df['SepalLengthCm'])
plt.title("Box Plot for SepalLengthCm")
# Out:
# Text(0.5, 1.0, 'Box Plot for SepalLengthCm')

# %% [markdown]
# we can observe that there is presence  outlier in the SepalWidthCm.
#
# #### As we impute the mean value we can also impute the outlier with mean, median, zero value in this methods. Since we imputing there is no loss of data. Here median is appropriate because it is not affected by outliers.

# %%
q1 = iris_df['SepalWidthCm'].quantile(0.25)
q3 = iris_df['SepalWidthCm'].quantile(0.75)
iqr = q3-q1
Lower_tail = q1 - 1.5 * iqr
Upper_tail = q3 + 1.5 * iqr
med = np.median(iris_df['SepalWidthCm'])
for i in iris_df['SepalWidthCm']:
    if i > Upper_tail or i < Lower_tail:
           iris_df['SepalWidthCm'] = iris_df['SepalWidthCm'].replace(i, med)
sns.boxplot(iris_df['SepalWidthCm'])
plt.title("Box Plot after median imputation")
plt.show()

# %%
iris_df.shape
# Out:
# (147, 5)

# %%
# Barplot describes the count of the class labels
print(iris_df['Species'].value_counts())
print("\n")
plt.figure(figsize = (12, 6))
sns.countplot(data =iris_df, x = 'Species')
plt.title("Species Count for each categories")
# Out:
# Iris-versicolor    50
# Iris-virginica     49
# Iris-setosa        48
# Name: Species, dtype: int64
# Text(0.5, 1.0, 'Species Count for each categories')

# %% [markdown]
# #### iris_df dataset is balanced dataset each categories of the Species contains equal number of the data after dealing with outlier so iris_df is balanced dataset
#
# ### Bivariate Analysis
#  using scatter plot we will find the relation of each feature with the Species. we have already observed in pairplot
#
#  #### 1. Relation SepalLengthCm and SepalWidthCm with Species of different categories

# %%
plt.figure(figsize=(10,8))
plt.title("Relation SepalLengthCm and SepalWidthCm with Species of different categories")
sns.scatterplot(iris_df["SepalLengthCm"],iris_df["SepalWidthCm"],hue =iris_df["Species"],s=75)
# Out:
# <AxesSubplot:title={'center':'Relation SepalLengthCm and SepalWidthCm with Species of different categories'}, xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# Here we can see that how Iris-versicolor, Iris-setosa andIris-virginica are related property in the SepalWidth and SepalLength
#
# 1)Iris-setosa species has smaller sepalLength but higher sepalWidth.
# 2)Iris-versicolor sepcies has average sepalLength and sepalWidth
# 3)Iris-virginica average SepalWidth and larger SepalLength
#
#
# #### 2.Relation PetalLengthCm and PetalWidthCm with Species of different categories

# %%
plt.figure(figsize=(10,8))
plt.title("Relation PetalLengthCm and petalWidthCm with Species of different categories")
sns.scatterplot(iris_df["PetalLengthCm"],iris_df["PetalWidthCm"],hue =iris_df["Species"],s=75)
# Out:
# <AxesSubplot:title={'center':'Relation PetalLengthCm and petalWidthCm with Species of different categories'}, xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# Here we can see that how Iris-versicolor, Iris-setosa and Iris-virginica are related property in the PetalWidth and PetalLength
#
# 1)Iris-setosa species has smaller PetalLength  and smaller PetalWidth.
# 2)Iris-versicolor sepcies has average PetalLength and PetalWidth
# 3)Iris-virginica  larger PetalLength and PetalWidth.
#
# #### Iris-setosa  species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# ### 3.correlation between the features:

# %%
print(iris_df.corr())
print("\n")
plt.figure(figsize=(9,6)) 
sns.heatmap(iris_df.corr(),annot=True) 
plt.show()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.110853       0.871305      0.817058
# SepalWidthCm       -0.110853      1.000000      -0.386424     -0.319336
# PetalLengthCm       0.871305     -0.386424       1.000000      0.961883
# PetalWidthCm        0.817058     -0.319336       0.961883      1.000000

# %% [markdown]
# Here we can visualize the correlation of each independent feature  with other
#
# 1)SepalWidthCm is negatively correlated with the other three
#
# 2)PetalLengthCm is positively correlated with the other two except SepalWidth
#
# 3)simillarly PetalWidth and SepalLength positively correlated with the other two except SepalWidth

# %%
sns.pairplot(iris_df,hue="Species")

# %% [markdown]
# #### we can observe from the above pairplot that distribution of the Iris-setosa is different from the other two species Iris-Versicolor and Iris-verginica. we can observe that the Iris-setosa have the smaller SepalLength,PetalWidth and PetalLength and larger SepalWidth.
#
# Based on petalLength we can classify the species as
#
# 1) petalLength <2.0 are belongs to Iris-setosa
#
# 2) petalLength > 2.0 and petalLength < 4.8 then species is Iris-Versicolor
#
# 3) petalLength > 4.8 then species is Iris-virginica
#
# but few of the Iris-versicolor and Iris-virginica will share the similar property
#
#
# ### Spliting the dataset in independent and dependent variables

# %%
#Spliting the dataset in independent and dependent variables
X = iris_df.drop(columns="Species")
y = (iris_df["Species"])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 82)

# %% [markdown]
# ### Feature Scaling to bring the variable in a single scale

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
#  #### Naive Bayes

# %%
# Fitting Naive Bayes Classification to the Training set with linear kernel
from sklearn.naive_bayes import GaussianNB
nvclassifier = GaussianNB()
nvclassifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Predicting the Test set results
y_pred = nvclassifier.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
Accuracy_percent_test = (metrics.accuracy_score(y_test,y_pred)) * 100
print("Gaussian Naive Bayes model accuracy for test dataset: "+str(Accuracy_percent_test))
# Out:
# Gaussian Naive Bayes model accuracy for test dataset: 100.0

# %% [markdown]
# ### Logistic regression

# %%
# model
from sklearn.linear_model import LogisticRegression
Lmodel = LogisticRegression()
Lmodel.fit(X_train, y_train)
y_pred1 = Lmodel.predict(X_test)

# %%
Accuracy_percent_test = (metrics.accuracy_score(y_test,y_pred1)) * 100
print("Logistic model accuracy for test dataset: "+str(Accuracy_percent_test))
# Out:
# Logistic model accuracy for test dataset: 100.0

# %% [markdown]
# ### SVM

# %%
# Fitting Kernel SVM to the Training set
from sklearn.svm import SVC
svm_model = SVC(gamma=0.001 , C = 100)
svm_model.fit(X_train, y_train)
y_pred2 = svm_model.predict(X_test)

# %%
Accuracy_percent_test = (metrics.accuracy_score(y_test,y_pred2)) * 100
print("svm model accuracy for test dataset: "+str(Accuracy_percent_test))
# Out:
# svm model accuracy for test dataset: 100.0
